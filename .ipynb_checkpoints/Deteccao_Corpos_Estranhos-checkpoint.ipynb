# %%
# Criando o array de imagens

import os
files_path = [os.path.abspath(x) for x in os.listdir('./') if x.endswith('.jpg')]
print(files_path)
# Out:
# ['/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio41.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio33.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio28.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio42.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio49.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio46.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio44.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio24.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio45.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio23.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio29.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio36.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio50.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio40.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio34.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio21.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio38.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio27.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio22.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio37.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio30.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio26.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio39.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio32.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio47.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio51.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio31.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio48.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio25.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio35.jpg', '/home/lucas/Documentos/UnB/10º_Semestre/Visao_Computacional/ProjetoFinalVisao/radio43.jpg']

# %%
# import cv2
import numpy as np
import matplotlib.pyplot as plt


## COLETAR AS BORDAS ===============================================








#=========================================================================


for i in range(50):

    ## NOME DA IMAGEM
    print('radio'+str(i+1)+'.jpg')
    
    ## Convertendo a imagem para escala de cinza

    imgNormal = cv2.imread('radio'+str(i+1)+'.jpg') 
    imgTeste = imgNormal
    imgTeste = cv2.cvtColor(imgTeste, cv2.COLOR_RGB2GRAY)
    print(imgTeste.shape)



    # DILATAR OS PIXELS DA IMAGEM VISANDO DESTACAR OS CORPOS ESTRANHOS MENORES

    ## elementoEstruturante
    elementoEstruturante = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
    imgTeste = cv2.dilate(imgTeste, elementoEstruturante, iterations = 4)



    plt.gray()
    plt.imshow(imgTeste)
    plt.show()


    
    # DETECTAR BORDAS
    
    
    

    ## Coletar o maior valor dos pixels da imagem (considerando corpo estranho denso)

    quantidadeLinhas, quantidadeColunas = imgTeste.shape

    maiorValorPixel = max([valor for quantidadeLinhas in imgTeste for valor in quantidadeLinhas])
    #print(maior)


    # SELECIONANDO PIXEL'S DE UM INTERVALO
    _, img2 = cv2.threshold(imgTeste, maiorValorPixel-40, maiorValorPixel, cv2.THRESH_BINARY_INV)

    plt.imshow(img2)
    plt.show()
# Out:
# (1494, 1800)
# radio1.jpg
# (1800, 1536)
# radio2.jpg
# (1800, 1446)
# radio3.jpg
# (1800, 1619)
# radio4.jpg
# (1800, 1781)
# radio5.jpg
# (1800, 1779)
# radio6.jpg
# (1470, 1800)
# radio7.jpg
# (1800, 1649)
# radio8.jpg
# (1800, 1647)
# radio9.jpg
# (1800, 1557)
# radio10.jpg
# (1800, 1257)
# radio11.jpg
# (1800, 1408)
# radio12.jpg
# (1800, 1518)
# radio13.jpg
# (1800, 1615)
# radio14.jpg
# (1800, 1368)
# radio15.jpg
# (1800, 1722)
# radio16.jpg
# (1370, 1800)
# radio17.jpg
# (1800, 1727)
# radio18.jpg
# (1656, 1800)
# radio19.jpg
# (1336, 1800)
# radio20.jpg
# (420, 512)
# radio21.jpg
# (582, 502)
# radio22.jpg
# (342, 455)
# radio23.jpg
# (682, 512)
# radio24.jpg
# (521, 512)
# radio25.jpg
# (604, 512)
# radio26.jpg
# (420, 512)
# radio27.jpg
# (624, 512)
# radio28.jpg
# (517, 512)
# radio29.jpg
# (582, 512)
# radio30.jpg
# (624, 512)
# radio31.jpg
# (624, 512)
# radio32.jpg
# (420, 512)
# radio33.jpg
# (624, 512)
# radio34.jpg
# (420, 512)
# radio35.jpg
# (624, 512)
# radio36.jpg
# (477, 512)
# radio37.jpg
# (565, 512)
# radio38.jpg
# (420, 512)
# radio39.jpg
# (420, 512)
# radio40.jpg
# (624, 512)
# radio41.jpg
# (624, 512)
# radio42.jpg
# (420, 512)
# radio43.jpg
# (420, 512)
# radio44.jpg
# (931, 730)
# radio45.jpg
# (503, 520)
# radio46.jpg
# (380, 253)
# radio47.jpg
# (496, 660)
# radio48.jpg
# (624, 512)
# radio49.jpg
# (420, 512)
# radio50.jpg

# %%
# FAZER UMA FUNÇÃO QUE ESCUREÇA GRANDES ÁREAS -- talvez com análise de um grupo de vizinhos?
# FAZER UMA FUNÇÃO QUE EVIDENCIE O CORPO ESTRANHO -- a mesma análise de visinhos
# outro esquema seria notar a mudança abrupta de nível de cinza!
